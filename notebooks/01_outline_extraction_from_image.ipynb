# %% [markdown]
# # 01 – Outline extraction from image
#
# This notebook demonstrates how to go from a raw diatom micrograph to a clean valve outline
# suitable for use in `data/outlines/`.
#
# See also: `code/analysis/extract_outline_from_image.py` for a script version of this pipeline.
#
# ---
#
# ## Steps
#
# 1. Load a grayscale micrograph.
# 2. Preprocess: denoise and enhance contrast.
# 3. Threshold to separate diatom from background.
# 4. Find the largest closed contour.
# 5. Normalize and save as SVG / CSV.

# %%
# TODO: Install dependencies if needed
# !pip install numpy scipy matplotlib scikit-image opencv-python

import numpy as np
import matplotlib.pyplot as plt

# TODO: import cv2 or skimage once image is available
print('Environment ready.')

# %% [markdown]
# ## 1. Load image
#
# Place a micrograph in `images/raw/` and update the path below.

# %%
# TODO: load image
# import cv2
# img = cv2.imread('../images/raw/centric_disc_example.jpg', cv2.IMREAD_GRAYSCALE)
# plt.imshow(img, cmap='gray')
# plt.title('Raw micrograph')
# plt.axis('off')
# plt.show()
print('TODO: load a micrograph from images/raw/')

# %% [markdown]
# ## 2. Preprocess
#
# Typical steps: Gaussian blur to suppress noise, CLAHE for contrast.

# %%
# TODO: preprocess
# blurred = cv2.GaussianBlur(img, (5, 5), 0)
# clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
# enhanced = clahe.apply(blurred)
print('TODO: preprocess image')

# %% [markdown]
# ## 3. Threshold and find contour

# %%
# TODO: threshold and extract contour
# _, binary = cv2.threshold(enhanced, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
# contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
# outline = max(contours, key=cv2.contourArea).squeeze()
# print(f'Found contour with {len(outline)} points')
print('TODO: threshold and find largest contour')

# %% [markdown]
# ## 4. Normalize and save
#
# Normalize to `[-1, 1]` on the longest axis, centred at origin.
# See `data/outlines/README.md` for the coordinate convention.

# %%
# TODO: normalize and save
# pts = outline.astype(float)
# pts -= pts.mean(axis=0)
# scale = np.abs(pts).max()
# pts /= scale
# np.savetxt('../data/outlines/my_diatom.csv', pts, delimiter=',', header='x,y', comments='')
print('TODO: normalize outline and save to data/outlines/')
