# %% [markdown]
# # 02 – Elliptic Fourier descriptors
#
# This notebook demonstrates how to compute **elliptic Fourier descriptors (EFDs)** from a diatom
# valve outline and reconstruct the shape at different harmonic counts.
#
# See also:
# - `code/analysis/compute_efd_descriptors.py` for a script version.
# - `data/outlines/README.md` for the expected input format.
# - `docs/03_math_and_geometry_models.md` for the mathematical background.
#
# ---
#
# ## Steps
#
# 1. Load an outline CSV from `data/outlines/`.
# 2. Compute EFD coefficients.
# 3. Reconstruct the outline at N = 5, 10, 20 harmonics and plot overlays.
# 4. Save coefficients to `data/descriptors/`.

# %%
# TODO: Install dependencies if needed
# !pip install numpy matplotlib pyefd

import numpy as np
import matplotlib.pyplot as plt

# TODO: import pyefd once an outline is available
print('Environment ready.')

# %% [markdown]
# ## 1. Load outline
#
# Place a CSV outline in `data/outlines/` (see notebook 01) and update the path below.

# %%
# TODO: load outline
# outline = np.loadtxt('../data/outlines/naviculoid_boat.csv', delimiter=',', skiprows=1)
# print(f'Loaded outline with {len(outline)} points')

# Synthetic example: unit circle as a placeholder
t = np.linspace(0, 2 * np.pi, 200, endpoint=False)
outline = np.column_stack([np.cos(t), np.sin(t)])
print(f'Using synthetic circle outline with {len(outline)} points')

plt.figure(figsize=(4, 4))
plt.plot(outline[:, 0], outline[:, 1], 'k-', lw=1)
plt.axis('equal')
plt.title('Input outline')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Compute EFD coefficients
#
# Using `pyefd.elliptic_fourier_descriptors()` (or implement manually via DFT).

# %%
# TODO: compute EFDs
# from pyefd import elliptic_fourier_descriptors, normalize_efd
# coeffs = elliptic_fourier_descriptors(outline, order=20)
# coeffs_normalized = normalize_efd(coeffs)
# print(f'EFD coefficients shape: {coeffs.shape}  (harmonics x 4)')
print('TODO: compute EFDs with pyefd or manual DFT')

# %% [markdown]
# ## 3. Reconstruct at different harmonic counts

# %%
# TODO: reconstruct at N = 5, 10, 20 harmonics and overlay
# from pyefd import reconstruct_contour
# fig, axes = plt.subplots(1, 3, figsize=(12, 4))
# for ax, n in zip(axes, [5, 10, 20]):
#     recon = reconstruct_contour(coeffs[:n], num_points=200)
#     ax.plot(outline[:, 0], outline[:, 1], 'k-', lw=1, label='original')
#     ax.plot(recon[:, 0], recon[:, 1], 'r--', lw=1.5, label=f'N={n}')
#     ax.set_title(f'{n} harmonics')
#     ax.axis('equal')
#     ax.legend(fontsize=8)
# plt.tight_layout()
# plt.show()
print('TODO: plot reconstructions at different harmonic counts')

# %% [markdown]
# ## 4. Save descriptors

# %%
# TODO: save EFD coefficients to data/descriptors/
# header = 'n,a_n,b_n,c_n,d_n'
# rows = np.column_stack([np.arange(1, len(coeffs)+1), coeffs])
# np.savetxt('../data/descriptors/naviculoid_boat_efd.csv', rows, delimiter=',', header=header, comments='')
print('TODO: save descriptors to data/descriptors/')
